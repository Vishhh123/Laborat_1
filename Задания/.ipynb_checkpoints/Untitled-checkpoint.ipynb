# %%
# !dir
# Out:
#  ’®¬ ў гбва®©бвўҐ C Ё¬ҐҐв ¬ҐвЄг Windows 11
#  ‘ҐаЁ©­л© ­®¬Ґа в®¬ : 5664-8371
#
#  ‘®¤Ґа¦Ё¬®Ґ Ї ЇЄЁ C:\Users\user\Laborat_1\‡ ¤ ­Ёп
#
# 12.06.2026  13:43    <DIR>          .
# 10.06.2026  14:25    <DIR>          ..
# 12.06.2026  13:32    <DIR>          .ipynb_checkpoints
# 12.06.2026  13:36               617 Untitled.ipynb
# 12.06.2026  12:52             1я927 zadanie_1.ipynb
# 12.06.2026  13:28             1я864 zadanie_2.ipynb
# 12.06.2026  13:28             9я765 zadanie_3.ipynb
#                4 д ©«®ў         14я173 Ў ©в
#                3 Ї Ї®Є  17я615я294я464 Ў ©в бў®Ў®¤­®

# %%
# !where python
# Out:
# C:\Users\user\anaconda3\python.exe
# C:\Program Files\Python313\python.exe
# C:\Users\user\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
# !mkdir test_folder

# %%
# !dir
# Out:
#  ’®¬ ў гбва®©бвўҐ C Ё¬ҐҐв ¬ҐвЄг Windows 11
#  ‘ҐаЁ©­л© ­®¬Ґа в®¬ : 5664-8371
#
#  ‘®¤Ґа¦Ё¬®Ґ Ї ЇЄЁ C:\Users\user\Laborat_1\‡ ¤ ­Ёп
#
# 12.06.2026  13:44    <DIR>          .
# 10.06.2026  14:25    <DIR>          ..
# 12.06.2026  13:32    <DIR>          .ipynb_checkpoints
# 12.06.2026  13:44    <DIR>          test_folder
# 12.06.2026  13:36               617 Untitled.ipynb
# 12.06.2026  12:52             1я927 zadanie_1.ipynb
# 12.06.2026  13:28             1я864 zadanie_2.ipynb
# 12.06.2026  13:28             9я765 zadanie_3.ipynb
#                4 д ©«®ў         14я173 Ў ©в
#                4 Ї Ї®Є  17я615я220я736 Ў ©в бў®Ў®¤­®

# %%
with open("my_file.txt", "w") as f:
    f.write("Тестовый текст")

# %%
# !move my_file.txt test_folder\
# Out:
# ЏҐаҐ¬ҐйҐ­® д ©«®ў:         1.

# %%
# !del test_folder\my_file.txt

# %%
# !rmdir test_folder

# %%
# !cls
