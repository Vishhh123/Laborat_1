# %% [markdown]
# # Практическое задание "№1"
#
# **Жирный текст** и *курсивный текст*.
#
# ### Нумерованный список:
# 1. Первый пункт
# 2. Второй пункт
# 3. Третий пункт
#
# ### Маркированный список:
# - Пункт А
# - Пункт Б
# - Пункт В
#
# ### Индивидуальное задание (вариант 25):
# **Базовое выражение для логарифма от произведения:**
#
# $$ \log_a(x \cdot y) = \log_a x + \log_a y $$

# %%
name = input("Введите ваше имя: ")
print(f"Привет, {name}! Добро пожаловать в Jupyter Notebook!")
# Out:
# Введите ваше имя:  Дарья
# Привет, Дарья! Добро пожаловать в Jupyter Notebook!
