# %%
import pandas as pd
df = pd.read_csv("../data/data.csv")
df.head()
# Out:
#     id             name               email
# 0  209     David Miller   a1g06v@company.co
# 1  815       Lisa Brown    nlrhpt@yahoo.com
# 2  969     Robert White   t3fljw@company.co
# 3  386    Noah Anderson  xtz64v@example.com
# 4  445  Robert Williams    pd2n98@gmail.com
